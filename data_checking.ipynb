# %%
import pandas as pd
import json

# read the data in Data Folder (this are json files)
train_data = pd.read_json('./Data/ticker_train_data.json')
test_data = pd.read_json('./Data/ticker_test_data.json')

# %%
train_data
# Out:
#           Date                                 Affected Companies
# 0   2020-09-01  {'CVX': 'negative', 'AAPL': 'positive', 'WMT':...
# 1   2020-09-02  {'AAPL': 'negative', 'GS': 'positive', 'MSFT':...
# 2   2020-09-03  {'DOW': 'positive', 'BA': 'positive', 'JPM': '...
# 3   2020-09-04  {'AAPL': 'negative', 'GS': 'positive', 'KO': '...
# 4   2020-09-08  {'AAPL': 'negative', 'VZ': 'positive', 'GS': '...
# ..         ...                                                ...
# 268 2021-09-24  {'AXP': 'neutral', 'AAPL': 'negative', 'BA': '...
# 269 2021-09-27  {'AAPL': 'negative', 'BA': 'positive', 'CVX': ...
# 270 2021-09-28  {'BA': 'neutral', 'GS': 'negative', 'HON': 'po...
# 271 2021-09-29  {'BA': 'positive', 'KO': 'positive', 'IBM': 'n...
# 272 2021-09-30  {'BA': 'positive', 'MRK': 'positive', 'KO': 'n...
#
# [273 rows x 2 columns]

# %%
test_data
# Out:
#           Date                                 Affected Companies
# 0   2021-10-01  {'HON': 'positive', 'MRK': 'positive', 'BA': '...
# 1   2021-10-04  {'CVX': 'neutral', 'GS': 'neutral', 'MCD': 'po...
# 2   2021-10-05  {'BA': 'negative', 'V': 'neutral', 'HON': 'neu...
# 3   2021-10-06  {'BA': 'neutral', 'CVX': 'positive', 'CSCO': '...
# 4   2021-10-07  {'IBM': 'negative', 'AMGN': 'positive', 'MSFT'...
# ..         ...                                                ...
# 310 2022-12-23  {'BA': 'neutral', 'AMGN': 'neutral', 'MSFT': '...
# 311 2022-12-27  {'BA': 'negative', 'DOW': 'neutral', 'GS': 'ne...
# 312 2022-12-28  {'NKE': 'positive', 'AAPL': 'negative', 'PG': ...
# 313 2022-12-29  {'CVX': 'negative', 'AAPL': 'negative', 'GS': ...
# 314 2022-12-30  {'MCD': 'positive', 'AAPL': 'neutral', 'VZ': '...
#
# [315 rows x 2 columns]
